# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
from datetime import datetime

# %%
acq = pd.read_csv(r"C:\Users\Anonymous\Downloads\Python Foundation Case Study 2 - Credit Card Case Study\Case Study 2 - Credit Card Case Study\Customer Acqusition.csv")
acq
# Out:
#      No Customer  Age        City   Product     Limit Company        Segment
# 0     1       A1   76   BANGALORE      Gold  500000.0      C1  Self Employed
# 1     2       A2   71    CALCUTTA    Silver  100000.0      C2   Salaried_MNC
# 2     3       A3   34      COCHIN  Platimum   10000.0      C3   Salaried_Pvt
# 3     4       A4   47      BOMBAY  Platimum   10001.0      C4           Govt
# 4     5       A5   56   BANGALORE  Platimum   10002.0      C5  Normal Salary
# ..  ...      ...  ...         ...       ...       ...     ...            ...
# 95   96      A96   54     CHENNAI    Silver  100000.0     C19   Salaried_Pvt
# 96   97      A97   58  TRIVANDRUM  Platimum   10000.0     C20           Govt
# 97   98      A98   51    CALCUTTA  Platimum   10001.0     C21  Normal Salary
# 98   99      A99   35    CALCUTTA  Platimum   10002.0     C22  Self Employed
# 99  100     A100   36      COCHIN    Silver  100000.0      C5   Salaried_MNC
#
# [100 rows x 8 columns]

# %%
repayment = pd.read_csv(r"C:\Users\Anonymous\Downloads\Python Foundation Case Study 2 - Credit Card Case Study\Case Study 2 - Credit Card Case Study\Repayment.csv")
repayment
# Out:
#       SL No: Customer      Month     Amount  Unnamed: 4
# 0        NaN       A1  12-Jan-04  495414.75         NaN
# 1        2.0       A1   3-Jan-04  245899.02         NaN
# 2        3.0       A1  15-Jan-04  259490.06         NaN
# 3        4.0       A1  25-Jan-04  437555.12         NaN
# 4        5.0       A1  17-Jan-05  165972.88         NaN
# ...      ...      ...        ...        ...         ...
# 1518     NaN      NaN        NaN        NaN         NaN
# 1519     NaN      NaN        NaN        NaN         NaN
# 1520     NaN      NaN        NaN        NaN         NaN
# 1521     NaN      NaN        NaN        NaN         NaN
# 1522     NaN      NaN        NaN        NaN         NaN
#
# [1523 rows x 5 columns]

# %%
spend = pd.read_csv(r"C:\Users\Anonymous\Downloads\Python Foundation Case Study 2 - Credit Card Case Study\Case Study 2 - Credit Card Case Study\spend.csv")
spend
# Out:
#       Sl No: Customer      Month        Type     Amount
# 0          1       A1  12-Jan-04   JEWELLERY  485470.80
# 1          2       A1   3-Jan-04       PETRO  410556.13
# 2          3       A1  15-Jan-04     CLOTHES   23740.46
# 3          4       A1  25-Jan-04        FOOD  484342.47
# 4          5       A1  17-Jan-05      CAMERA  369694.07
# ...      ...      ...        ...         ...        ...
# 1495    1496      A67   4-Feb-06  BUS TICKET  356872.73
# 1496    1497      A68  25-Mar-06  BUS TICKET  204971.10
# 1497    1498      A69  31-Mar-06  BUS TICKET   50449.44
# 1498    1499      A70  23-Mar-06  BUS TICKET   80593.94
# 1499    1500      A71  24-Mar-06  BUS TICKET  194447.62
#
# [1500 rows x 5 columns]

# %%
cc_data = pd.read_excel(r"C:\Users\Anonymous\Downloads\Python Foundation Case Study 2 - Credit Card Case Study\Case Study 2 - Credit Card Case Study\Credit Card Data.xlsx")
cc_data
# Out:
#      No Customer        Age        City   Product   Limit Company  \
# 0     1       A1  34.012349   BANGALORE      Gold  500000      C1
# 1     2       A2  50.497350    CALCUTTA    Silver  100000      C2
# 2     3       A3  35.855817      COCHIN  Platimum   10000      C3
# 3     4       A4  27.356821      BOMBAY  Platimum   10001      C4
# 4     5       A5  22.021249   BANGALORE  Platimum   10002      C5
# ..  ...      ...        ...         ...       ...     ...     ...
# 95   96      A96  71.083162     CHENNAI    Silver  100000     C19
# 96   97      A97  69.880658  TRIVANDRUM  Platimum   10000     C20
# 97   98      A98  20.951811    CALCUTTA  Platimum   10001     C21
# 98   99      A99  52.456908    CALCUTTA  Platimum   10002     C22
# 99  100     A100   8.729077      COCHIN    Silver  100000      C5
#
#           Segment
# 0   Self Employed
# 1    Salaried_MNC
# 2    Salaried_Pvt
# 3            Govt
# 4   Normal Salary
# ..            ...
# 95   Salaried_Pvt
# ...

# %%
cc_data[cc_data['Age'] < 18.00]
# Out:
#      No Customer        Age        City   Product   Limit Company  \
# 10   11      A11   8.761067      COCHIN      Gold  500000     C11
# 12   13      A13  14.750376   BANGALORE      Gold  500000     C13
# 14   15      A15  10.031215    CALCUTTA      Gold  500000     C15
# 16   17      A17   0.391231      BOMBAY      Gold  500000     C17
# 18   19      A19   9.468325   BANGALORE  Platimum   10000     C19
# 21   22      A22  17.939749      BOMBAY    Silver  100000     C22
# 26   27      A27   4.131399     CHENNAI      Gold  500000      C9
# 30   31      A31  12.793322    CALCUTTA      Gold  500000     C13
# 32   33      A33   6.079612      BOMBAY  Platimum   10002     C15
# 34   35      A35  14.099055      COCHIN  Platimum  100001     C17
# 35   36      A36   6.805031      BOMBAY  Platimum  100002     C18
# 39   40      A40   0.828387    CALCUTTA  Platimum  500000     C22
# 42   43      A43   6.030805   BANGALORE      Gold  500000     C25
# ...

# %% [markdown]
# ### 1.
# ###  a. In case age is less than 18, replace it with mean of age values.

# %%
acq.loc[acq['Age'] < 18 ,'Age'] = acq['Age'].mean()
acq
# Out:
#      No Customer   Age        City   Product     Limit Company        Segment
# 0     1       A1  76.0   BANGALORE      Gold  500000.0      C1  Self Employed
# 1     2       A2  71.0    CALCUTTA    Silver  100000.0      C2   Salaried_MNC
# 2     3       A3  34.0      COCHIN  Platimum   10000.0      C3   Salaried_Pvt
# 3     4       A4  47.0      BOMBAY  Platimum   10001.0      C4           Govt
# 4     5       A5  56.0   BANGALORE  Platimum   10002.0      C5  Normal Salary
# ..  ...      ...   ...         ...       ...       ...     ...            ...
# 95   96      A96  54.0     CHENNAI    Silver  100000.0     C19   Salaried_Pvt
# 96   97      A97  58.0  TRIVANDRUM  Platimum   10000.0     C20           Govt
# 97   98      A98  51.0    CALCUTTA  Platimum   10001.0     C21  Normal Salary
# 98   99      A99  35.0    CALCUTTA  Platimum   10002.0     C22  Self Employed
# 99  100     A100  36.0      COCHIN    Silver  100000.0      C5   Salaried_MNC
#
# [100 rows x 8 columns]

# %% [markdown]
# ### b. In case spend amount is more than the limit, replace it with 50% of that customer’s limit. (customer’s limit provided in acquisition table is the per transaction limit on his card)

# %%
customer_spend = pd.merge(acq,spend,on ='Customer' ,how = 'inner')
customer_spend
# Out:
#        No Customer   Age        City   Product     Limit Company  \
# 0       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 1       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 2       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 3       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 4       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# ...   ...      ...   ...         ...       ...       ...     ...
# 1495   96      A96  54.0     CHENNAI    Silver  100000.0     C19
# 1496   97      A97  58.0  TRIVANDRUM  Platimum   10000.0     C20
# 1497   98      A98  51.0    CALCUTTA  Platimum   10001.0     C21
# 1498   99      A99  35.0    CALCUTTA  Platimum   10002.0     C22
# 1499  100     A100  36.0      COCHIN    Silver  100000.0      C5
#
#             Segment  Sl No:      Month        Type     Amount
# 0     Self Employed       1  12-Jan-04   JEWELLERY  485470.80
# ...

# %%
customer_spend.loc[customer_spend['Amount'] > customer_spend['Limit'],'Amount'] =  customer_spend['Limit'] * 0.5

# %%
customer_spend
# Out:
#        No Customer   Age        City   Product     Limit Company  \
# 0       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 1       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 2       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 3       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 4       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# ...   ...      ...   ...         ...       ...       ...     ...
# 1495   96      A96  54.0     CHENNAI    Silver  100000.0     C19
# 1496   97      A97  58.0  TRIVANDRUM  Platimum   10000.0     C20
# 1497   98      A98  51.0    CALCUTTA  Platimum   10001.0     C21
# 1498   99      A99  35.0    CALCUTTA  Platimum   10002.0     C22
# 1499  100     A100  36.0      COCHIN    Silver  100000.0      C5
#
#             Segment  Sl No:      Month        Type     Amount
# 0     Self Employed       1  12-Jan-04   JEWELLERY  485470.80
# ...

# %% [markdown]
# ###  c. Incase the repayment amount is more than the limit, replace the repayment with the limit.

# %%
cust_repayment = pd.merge(acq,repayment, on = 'Customer', how = 'inner')
cust_repayment
# Out:
#        No Customer   Age        City   Product     Limit Company  \
# 0       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 1       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 2       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 3       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 4       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# ...   ...      ...   ...         ...       ...       ...     ...
# 1495   96      A96  54.0     CHENNAI    Silver  100000.0     C19
# 1496   97      A97  58.0  TRIVANDRUM  Platimum   10000.0     C20
# 1497   98      A98  51.0    CALCUTTA  Platimum   10001.0     C21
# 1498   99      A99  35.0    CALCUTTA  Platimum   10002.0     C22
# 1499  100     A100  36.0      COCHIN    Silver  100000.0      C5
#
#             Segment  SL No:      Month     Amount  Unnamed: 4
# 0     Self Employed     NaN  12-Jan-04  495414.75         NaN
# ...

# %%
cust_repayment.loc[cust_repayment['Amount'] > cust_repayment['Limit'],'Amount'] = cust_repayment['Limit']
cust_repayment
# Out:
#        No Customer   Age        City   Product     Limit Company  \
# 0       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 1       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 2       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 3       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 4       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# ...   ...      ...   ...         ...       ...       ...     ...
# 1495   96      A96  54.0     CHENNAI    Silver  100000.0     C19
# 1496   97      A97  58.0  TRIVANDRUM  Platimum   10000.0     C20
# 1497   98      A98  51.0    CALCUTTA  Platimum   10001.0     C21
# 1498   99      A99  35.0    CALCUTTA  Platimum   10002.0     C22
# 1499  100     A100  36.0      COCHIN    Silver  100000.0      C5
#
#             Segment  SL No:      Month     Amount  Unnamed: 4
# 0     Self Employed     NaN  12-Jan-04  495414.75         NaN
# ...

# %% [markdown]
# ### 2. From the above dataset create the following summaries:
# ### a. How many distinct customers exist?

# %%
cc_data['Customer'].nunique()
# Out:
# 100

# %% [markdown]
# ###  b. How many distinct categories exist?

# %%
cc_data['Segment'].nunique()
# Out:
# 5

# %% [markdown]
# ###  c. What is the average monthly spend by customers?

# %%
spend['Month'] = pd.to_datetime(spend['Month'])  #first convert date into proper date format
spend['Month_Name'] = spend['Month'].apply(lambda x : pd.Timestamp.strftime(x,format = '%B')) # making separate month_name & year_name column for grouping
spend['Year'] = spend['Month'].apply(lambda x : pd.Timestamp.strftime(x, format='%Y'))
spend
# Out:
# C:\Users\Anonymous\AppData\Local\Temp\ipykernel_8064\1922463227.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   spend['Month'] = pd.to_datetime(spend['Month'])  #first convert date into proper date format
#       Sl No: Customer      Month        Type     Amount Month_Name  Year
# 0          1       A1 2004-01-12   JEWELLERY  485470.80    January  2004
# 1          2       A1 2004-01-03       PETRO  410556.13    January  2004
# 2          3       A1 2004-01-15     CLOTHES   23740.46    January  2004
# 3          4       A1 2004-01-25        FOOD  484342.47    January  2004
# 4          5       A1 2005-01-17      CAMERA  369694.07    January  2005
# ...      ...      ...        ...         ...        ...        ...   ...
# 1495    1496      A67 2006-02-04  BUS TICKET  356872.73   February  2006
# ...

# %%
pd.pivot_table(spend,index=['Month_Name'],values = 'Amount', aggfunc = 'mean')
# Out:
#                    Amount
# Month_Name
# April       236671.847533
# August      236056.328571
# December    208987.020357
# February    233037.216471
# January     256221.133553
# July        268042.287143
# June        241329.181250
# March       246255.783723
# May         241277.023476
# November    249099.824405
# October     215352.487857
# September   219369.892143

# %% [markdown]
# ###  d. What is the average monthly repayment by customers?

# %%
repayment['Month'] = pd.to_datetime(repayment['Month'], errors='coerce')  
repayment['Month_name'] = repayment['Month'].dt.strftime('%B')
repayment
# Out:
# C:\Users\Anonymous\AppData\Local\Temp\ipykernel_8064\2195626300.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   repayment['Month'] = pd.to_datetime(repayment['Month'], errors='coerce')
#       SL No: Customer      Month     Amount  Unnamed: 4 Month_name
# 0        NaN       A1 2004-01-12  495414.75         NaN    January
# 1        2.0       A1 2004-01-03  245899.02         NaN    January
# 2        3.0       A1 2004-01-15  259490.06         NaN    January
# 3        4.0       A1 2004-01-25  437555.12         NaN    January
# 4        5.0       A1 2005-01-17  165972.88         NaN    January
# ...      ...      ...        ...        ...         ...        ...
# 1518     NaN      NaN        NaT        NaN         NaN        NaN
# 1519     NaN      NaN        NaT        NaN         NaN        NaN
# ...

# %%
pd.pivot_table(repayment,index = 'Month_name', values = 'Amount', aggfunc = 'mean')
# Out:
#                    Amount
# Month_name
# April       259649.413200
# August      254564.734898
# December    286557.952500
# February    248756.162368
# January     245121.019624
# July        253512.325102
# June        220647.477083
# March       241654.966393
# May         257669.622782
# November    229867.344524
# October     240307.718333
# September   226865.354750

# %% [markdown]
# ### e. If the monthly rate of interest is 2.9%, what is the profit for the bank for each month?

# %%
customer_spend_repayment = pd.merge(customer_spend,cust_repayment, on = ['Customer'] , how = 'outer')
customer_spend_repayment.rename(columns={"Amount_x":"Spend_Amount","Amount_y":"Repay_Amount"},inplace=True)
customer_spend_repayment['Month_x'] = pd.to_datetime(customer_spend_repayment['Month_x'],format = '%d-%b-%y' )
customer_spend_repayment['Month_y'] = pd.to_datetime(customer_spend_repayment['Month_y'],format = '%d-%b-%y' )
customer_spend_repayment['Month_Name'] = customer_spend_repayment['Month_x'].dt.strftime('%B')
spend_and_repay = pd.pivot_table(customer_spend_repayment,index = 'Month_Name', values = ['Spend_Amount','Repay_Amount'], aggfunc = 'sum')
spend_and_repay
# Out:
#             Repay_Amount  Spend_Amount
# Month_Name
# April       6.031293e+08  5.295670e+08
# August      2.045258e+08  1.887379e+08
# December    1.113839e+08  7.618486e+07
# February    1.062241e+09  9.257089e+08
# January     1.405396e+09  1.339083e+09
# July        1.970459e+08  1.981980e+08
# June        2.873648e+08  2.920392e+08
# March       8.685055e+08  7.609884e+08
# May         9.335925e+08  8.536754e+08
# November    3.509376e+08  3.160606e+08
# October     1.274195e+08  1.014081e+08
# September   1.937785e+08  1.663367e+08

# %%
spend_and_repay['Profit'] = spend_and_repay['Repay_Amount'] - spend_and_repay['Spend_Amount']
spend_and_repay
# Out:
#             Repay_Amount  Spend_Amount        Profit
# Month_Name
# April       6.031293e+08  5.295670e+08  7.356235e+07
# August      2.045258e+08  1.887379e+08  1.578782e+07
# December    1.113839e+08  7.618486e+07  3.519905e+07
# February    1.062241e+09  9.257089e+08  1.365318e+08
# January     1.405396e+09  1.339083e+09  6.631363e+07
# July        1.970459e+08  1.981980e+08 -1.152053e+06
# June        2.873648e+08  2.920392e+08 -4.674368e+06
# March       8.685055e+08  7.609884e+08  1.075171e+08
# May         9.335925e+08  8.536754e+08  7.991709e+07
# November    3.509376e+08  3.160606e+08  3.487701e+07
# October     1.274195e+08  1.014081e+08  2.601133e+07
# September   1.937785e+08  1.663367e+08  2.744174e+07

# %%
spend_and_repay = spend_and_repay[spend_and_repay['Profit'] > 0] 
spend_and_repay['Interest Earned'] = spend_and_repay['Profit'] * 0.029
spend_and_repay
# Out:
# C:\Users\Anonymous\AppData\Local\Temp\ipykernel_8064\2589357458.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spend_and_repay['Interest Earned'] = spend_and_repay['Profit'] * 0.029
#             Repay_Amount  Spend_Amount        Profit  Interest Earned
# Month_Name
# April       6.031293e+08  5.295670e+08  7.356235e+07     2.133308e+06
# August      2.045258e+08  1.887379e+08  1.578782e+07     4.578467e+05
# December    1.113839e+08  7.618486e+07  3.519905e+07     1.020772e+06
# February    1.062241e+09  9.257089e+08  1.365318e+08     3.959421e+06
# January     1.405396e+09  1.339083e+09  6.631363e+07     1.923095e+06
# March       8.685055e+08  7.609884e+08  1.075171e+08     3.117997e+06
# ...

# %%
spend_and_repay['Interest Earned'].plot(kind = 'bar')
plt.xlabel('MONTH')
plt.ylabel('INTEREST EARNED')
plt.title('VARIATION OF INTEREST EARNING OVER MONTHS')
plt.show()

# %% [markdown]
# ###  f. What are the top 5 product types?

# %%
spend['Type'].value_counts().head()
# Out:
# Type
# PETRO           200
# FOOD            160
# CAMERA          160
# AIR TICKET      147
# TRAIN TICKET    132
# Name: count, dtype: int64

# %% [markdown]
# ### g. Which city is having maximum spend?

# %%
spend_acq = pd.merge(acq,spend,on = 'Customer' , how = 'inner')
spend_acq
# Out:
#        No Customer   Age        City   Product     Limit Company  \
# 0       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 1       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 2       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 3       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 4       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# ...   ...      ...   ...         ...       ...       ...     ...
# 1495   96      A96  54.0     CHENNAI    Silver  100000.0     C19
# 1496   97      A97  58.0  TRIVANDRUM  Platimum   10000.0     C20
# 1497   98      A98  51.0    CALCUTTA  Platimum   10001.0     C21
# 1498   99      A99  35.0    CALCUTTA  Platimum   10002.0     C22
# 1499  100     A100  36.0      COCHIN    Silver  100000.0      C5
#
#             Segment  Sl No:      Month        Type     Amount Month_Name  Year
# 0     Self Employed       1 2004-01-12   JEWELLERY  485470.80    January  2004
# ...

# %%
pd.pivot_table(spend_acq,index='City',values = 'Amount').sort_values(by ='Amount',ascending=False).head(1)
# Out:
#                  Amount
# City
# CALCUTTA  256636.494064

# %% [markdown]
# ### h. Which age group is spending more money?

# %%
spend_acq['Age_Group'] = pd.cut(spend_acq['Age'],bins=np.arange(18,88,8),labels=["18-26","26-34", "34-42" ,"42-50" ,"50-58","58-66","66-74","74-82"],include_lowest=True)
spend_acq
# Out:
#        No Customer   Age        City   Product     Limit Company  \
# 0       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 1       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 2       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 3       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 4       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# ...   ...      ...   ...         ...       ...       ...     ...
# 1495   96      A96  54.0     CHENNAI    Silver  100000.0     C19
# 1496   97      A97  58.0  TRIVANDRUM  Platimum   10000.0     C20
# 1497   98      A98  51.0    CALCUTTA  Platimum   10001.0     C21
# 1498   99      A99  35.0    CALCUTTA  Platimum   10002.0     C22
# 1499  100     A100  36.0      COCHIN    Silver  100000.0      C5
#
#             Segment  Sl No:      Month        Type     Amount Month_Name  \
# 0     Self Employed       1 2004-01-12   JEWELLERY  485470.80    January
# ...

# %%
spend_acq.groupby(by = 'Age_Group')['Amount'].sum().sort_values(ascending = False)
# Out:
# Age_Group
# 26-34    71076544.85
# 42-50    65514131.53
# 34-42    61658185.23
# 50-58    48600571.86
# 18-26    34913392.94
# 66-74    33550294.60
# 58-66    27096196.49
# 74-82    22234756.69
# Name: Amount, dtype: float64

# %% [markdown]
# ### i. Who are the top 10 customers in terms of repayment?

# %%
repayment.groupby('Customer')['Amount'].sum().sort_values(ascending=False).head(10)
# Out:
# Customer
# A61    10539142.91
# A60     9876290.74
# A13     9572000.66
# A22     9372561.68
# A21     9056336.15
# A43     8489871.46
# A45     8448334.87
# A12     8334760.16
# A48     8292416.75
# A14     7943268.63
# Name: Amount, dtype: float64

# %% [markdown]
# ### 3. Calculate the city wise spend on each product on yearly basis. Also include a graphical representation for the same.

# %%
city_wise_spend = pd.pivot_table(spend_acq,index = ['City','Year'],columns = 'Product',values = 'Amount',aggfunc = 'sum')
city_wise_spend
# Out:
# Product                 Gold     Platimum      Silver
# City       Year
# BANGALORE  2004   9289878.54   6046763.93  6773901.65
#            2005  12892362.99   7784194.68  3936068.22
#            2006  12030611.09   5620904.86  4967945.66
# BOMBAY     2004   6987853.53   5199581.00  3061805.08
#            2005   8983018.28   5134074.48  2368375.97
#            2006   7917144.31   7547549.72  3628864.37
# CALCUTTA   2004   7477140.98   5961165.93  3321963.10
#            2005  10303355.80   8810284.03  1285609.11
#            2006  11167532.77  11305526.03  4783182.26
# CHENNAI    2004   1059618.50   5558572.68  1156129.37
#            2005   3740945.58   8868435.43  1000540.48
#            2006   2704288.62   6921130.79  1665326.62
# COCHIN     2004   7315850.15   8472832.23  4587738.70
#            2005  12110613.03  10856722.82  2619231.25
#            2006  10499142.38  12453968.83  4579249.87
# DELHI      2004   2806495.00   1565199.90  4293224.28
# ...

# %%
city_wise_spend.plot(kind = 'bar',figsize = (15,5))
plt.ylabel('Amount Spent')
plt.xlabel('City')
plt.title('Amount spent by customers by year and city')
plt.show()

# %% [markdown]
# ### 4. Create graphs for
# ### a. Monthly comparison of total spends, city wise

# %%
city_wise_monthly_spend = pd.pivot_table(spend_acq,index = 'City',columns= 'Month_Name',values = 'Amount', aggfunc = 'sum')
city_wise_monthly_spend
# Out:
# Month_Name       April      August    December     February      January  \
# City
# BANGALORE   6182081.72  1552898.45   722473.97   9875860.87  17782487.66
# BOMBAY      3726382.34  1066744.75   604939.17   7813534.61  10681854.60
# CALCUTTA    6883832.96  2179294.85   456826.68  11449586.70  14163384.38
# CHENNAI     3231144.38   681577.16   223628.27   5866408.35   7649568.68
# COCHIN      7070107.83  2582997.08  2011774.32   9459367.08  18692606.60
# DELHI       2845176.75   475893.81   967169.49   3072043.85   7373794.37
# PATNA       2786278.83   813559.15   223902.41   3466726.76   7388720.78
# TRIVANDRUM  2775772.32   561400.55   640922.26   4459329.30   5688758.54
#
# Month_Name        July        June        March          May    November  \
# City
# BANGALORE   3737413.09  1382739.41  10765773.46  10743668.90  3435745.65
# BOMBAY       612457.59  1486412.18   9857699.82   6974931.87  5120665.55
# CALCUTTA    2323261.43  2693423.54  10076115.86   7868030.30  3490771.91
# ...

# %%
city_wise_monthly_spend.plot(kind = 'bar', figsize = (16,5))
plt.xlabel('CITY NAME')
plt.ylabel('AMOUNT SPENT')
plt.show()

# %% [markdown]
# ###  b. Comparison of yearly spend on air tickets.

# %%
air_tkt = spend_acq[spend_acq['Type']=='AIR TICKET']
air_tkt
# Out:
#       No Customer   Age       City   Product     Limit Company        Segment  \
# 9      1       A1  76.0  BANGALORE      Gold  500000.0      C1  Self Employed
# 63     5       A5  56.0  BANGALORE  Platimum   10002.0      C5  Normal Salary
# 80     6       A6  70.0      DELHI    Silver  100000.0      C6  Self Employed
# 97     7       A7  26.0     COCHIN    Silver  100001.0      C7   Salaried_MNC
# 115    8       A8  67.0      PATNA    Silver  100002.0      C8   Salaried_Pvt
# ...   ..      ...   ...        ...       ...       ...     ...            ...
# 1474  75      A75  36.0     BOMBAY    Silver  100003.0     C37  Self Employed
# 1475  76      A76  66.0  BANGALORE    Silver  500000.0     C38  Self Employed
# 1476  77      A77  35.0  BANGALORE    Silver  500000.0     C39  Self Employed
# 1483  84      A84  70.0      PATNA    Silver  100000.0      C7           Govt
# 1498  99      A99  35.0   CALCUTTA  Platimum   10002.0     C22  Self Employed
#
# ...

# %%
pd.pivot_table(air_tkt,index='Year', values='Amount',aggfunc = 'sum')
# Out:
#            Amount
# Year
# 2004   8370914.59
# 2005  14495718.73
# 2006  10088812.10

# %%
pd.pivot_table(air_tkt,index='Year', values='Amount',aggfunc = 'sum').plot(kind = 'bar')
plt.xlabel('YEAR')
plt.ylabel('AMOUNT SPENT')
plt.show()

# %% [markdown]
# ### c. Comparison of monthly spend for each product (look for any seasonality that exists in terms of spend)

# %%
monthly_expenditure = pd.pivot_table(spend_acq,index ='Product' , columns = 'Month_Name', values = 'Amount', aggfunc = 'sum')
monthly_expenditure
# Out:
# Month_Name        April      August    December     February      January  \
# Product
# Gold        13170572.59  4954030.42  2332940.96  24779179.55  32413831.83
# Platimum    12798498.34  3892605.15  2951972.85  22081411.74  35212526.96
# Silver       9531706.20  1067730.23   566722.76   8602266.23  21794816.82
#
# Month_Name        July        June        March          May    November  \
# Product
# Gold        5167416.37  6538862.64  19256972.48  21548169.76  9203267.46
# Platimum    3695098.37  4756418.62  22639437.70  19380600.97  7977852.48
# Silver      2395261.32  2219152.89  14988675.86   9739404.20  3743265.31
#
# Month_Name     October   September
# Product
# Gold        3018223.38  3816887.62
# Platimum    2517051.91  3411278.13
# Silver       494594.37  1985369.72

# %%
monthly_expenditure.plot(kind = 'bar', figsize = (18,4))
plt.xlabel('PRODUCT')
plt.ylabel('AMOUNT SPENT')
plt.show()

# %%
print('The above chart shows that customers(throughout Gold , Silver and Platinum) tend to spend more in the month of JANUARY')
# Out:
# The above chart shows that customers(throughout Gold , Silver and Platinum) tend to spend more in the month of JANUARY

# %% [markdown]
# ### 5. Write user defined PYTHON function to perform the following analysis:You need to find top 10 customers for each city in terms of their repayment amount by different products and by different time periods i.e. year or month. The user should be able to specify the product (Gold/Silver/Platinum) and time period (yearly or monthly) and the function should automatically take these inputs while identifying the top 10 customers.

# %%
cust_repayment
# Out:
#        No Customer   Age        City   Product     Limit Company  \
# 0       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 1       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 2       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 3       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# 4       1       A1  76.0   BANGALORE      Gold  500000.0      C1
# ...   ...      ...   ...         ...       ...       ...     ...
# 1495   96      A96  54.0     CHENNAI    Silver  100000.0     C19
# 1496   97      A97  58.0  TRIVANDRUM  Platimum   10000.0     C20
# 1497   98      A98  51.0    CALCUTTA  Platimum   10001.0     C21
# 1498   99      A99  35.0    CALCUTTA  Platimum   10002.0     C22
# 1499  100     A100  36.0      COCHIN    Silver  100000.0      C5
#
#             Segment  SL No:      Month     Amount  Unnamed: 4
# 0     Self Employed     NaN  12-Jan-04  495414.75         NaN
# ...

# %%
cust_repayment['Month'] = pd.to_datetime(cust_repayment['Month'],format = '%d-%b-%y')

# %%
cust_repayment['Monthly'] = cust_repayment['Month'].apply(lambda x:pd.Timestamp.strftime(x,format="%B"))
cust_repayment['Yearly'] = cust_repayment['Month'].apply(lambda x:pd.Timestamp.strftime(x,format="%Y"))
cust_repayment.head()
# Out:
#    No Customer   Age       City Product     Limit Company        Segment  \
# 0   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 1   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 2   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 3   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
# 4   1       A1  76.0  BANGALORE    Gold  500000.0      C1  Self Employed
#
#    SL No:      Month     Amount  Unnamed: 4  Monthly Yearly
# 0     NaN 2004-01-12  495414.75         NaN  January   2004
# 1     2.0 2004-01-03  245899.02         NaN  January   2004
# 2     3.0 2004-01-15  259490.06         NaN  January   2004
# 3     4.0 2004-01-25  437555.12         NaN  January   2004
# 4     5.0 2005-01-17  165972.88         NaN  January   2005

# %%
def summary_report(product,timeperiod):
    
    if product.lower()=='gold' and timeperiod.lower()=='monthly':
        pivot = cust_repayment.pivot_table(index=['Product','City','Customer'],columns='Monthly',aggfunc='sum',values='Amount')
        result = pivot.loc[('Gold',['BANGALORE','COCHIN','CALCUTTA','BOMBAY','CHENNAI','TRIVANDRUM','PATNA','DELHI']),:]
    elif product.lower()=='gold' and timeperiod.lower()=='yearly':
        pivot = cust_repayment.pivot_table(index=['Product','City','Customer'],columns='Yearly',aggfunc='sum',values='Amount')
        result = pivot.loc[('Gold',['BANGALORE','COCHIN','CALCUTTA','BOMBAY','CHENNAI','TRIVANDRUM','PATNA','DELHI']),:]
    elif product.lower()=='silver' and timeperiod.lower()=='monthly':
        pivot = cust_repayment.pivot_table(index=['Product','City','Customer'],columns='Monthly',aggfunc='sum',values='Amount')
        result = pivot.loc[('Silver',['BANGALORE','COCHIN','CALCUTTA','BOMBAY','CHENNAI','TRIVANDRUM','PATNA','DELHI']),:]
    elif product.lower()=='silver' and timeperiod.lower()=='yearly':
        pivot = cust_repayment.pivot_table(index=['Product','City','Customer'],columns='Yearly',aggfunc='sum',values='Amount')
        result = pivot.loc[('Silver',['BANGALORE','COCHIN','CALCUTTA','BOMBAY','CHENNAI','TRIVANDRUM','PATNA','DELHI']),:]
    if product.lower()=='platinum' and timeperiod.lower()=='monthly':
        pivot = cust_repayment.pivot_table(index=['Product','City','Customer'],columns='Monthly',aggfunc='sum',values='Amount')
        result = pivot.loc[('Platinum',['BANGALORE','COCHIN','CALCUTTA','BOMBAY','CHENNAI','TRIVANDRUM','PATNA','DELHI']),:]
    elif product.lower()=='platinum' and timeperiod.lower()=='yearly':
        pivot = cust_repayment.pivot_table(index=['Product','City','Customer'],columns='Yearly',aggfunc='sum',values='Amount')
        result = pivot.loc[('Platinum',['BANGALORE','COCHIN','CALCUTTA','BOMBAY','CHENNAI','TRIVANDRUM','PATNA','DELHI']),:]
    return result

# %%
summary_report('silver','yearly')
# Out:
# Yearly                             2004        2005        2006
# Product City       Customer
# Silver  BANGALORE  A18        491592.71   638296.41   700000.00
#                    A23        664965.71  1000010.00   872925.32
#                    A59        676557.50   427247.08   600018.00
#                    A72        100000.00         NaN         NaN
#                    A76              NaN   265619.05         NaN
#                    A77              NaN         NaN     3159.62
#         COCHIN     A100        69551.19         NaN         NaN
#                    A25        786338.08   611555.69  1000030.00
#                    A7         500005.00   422177.27   608997.87
#                    A74              NaN   100002.00         NaN
#                    A79              NaN         NaN   193230.31
#         CALCUTTA   A2         400000.00   410274.00   200000.00
#                    A58        533815.62   540173.85   411640.17
# ...
